# %% [markdown]
# <a href="https://colab.research.google.com/github/subjekt-iv/styleGAN2-ModernArt/blob/main/subjektiv-faces-multi_pkl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu May 26 15:01:01 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 1.x

# !git clone https://github.com/dvschultz/stylegan2
# !pip install opensimplex # needed for noise interpolation
# %cd stylegan2
# %mkdir datasets
# Out:
# TensorFlow 1.x selected.
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 552, done.
# remote: Total 552 (delta 0), reused 0 (delta 0), pack-reused 552
# Receiving objects: 100% (552/552), 22.47 MiB | 23.34 MiB/s, done.
# Resolving deltas: 100% (285/285), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opensimplex
#   Downloading opensimplex-0.4.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from opensimplex) (1.21.6)
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.4.2
# /content/stylegan2

# %% [markdown]
# #Converting your dataset
# StyleGAN requires you to convert your standard jpg or png images into a new format (.tfrecords). I recommend doing this on your server because the files become quite large and will be slow to upload over FTP.
#
# After the `create_from_images` argument you need to pass in two paths. The first path is where the .tfrecords files should be output (just edit the last part to have a unique name). The second path is to the directory of your images.

# %%
# !python dataset_tool.py create_from_images ./datasets/carassubjektivdataset ./carassbjktv
# Out:
# Loading images from "./carassbjktv"
# Error: No input images found

# %% [markdown]
# #Test the model
# The following command will generate 55 sample images from the model.
#
# ##Options
# `--network`
#
# Make sure the `--network` argument points to your .pkl file. (My preferred method is to right click on the file in the Files pane to your left and choose `Copy Path`, then paste that into the argument after the `=` sign).
#
# `--seeds`
#
# This allows you to choose random seeds from the model. Remember that our input to StyleGAN is a 512-dimensional array. These seeds will generate those 512 values. Each seed will generate a different, random array. The same seed value will also always generate the same random array, so we can later use it for other purposes like interpolation.
#
# `--truncation-psi`
#
# Truncation is a special argument of StyleGAN. Essentially values that are closer to 0 will be more real than numbers further away from 0. I generally recommend a value between `0.5` and `1.0`. `0.5` will give you pretty "realistic" results, while `1.0` is likely to give you "weirder" results.

# %%
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --id 10_kHlOhSss_fo0nslmzVYQj1r8m85lyt
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=10_kHlOhSss_fo0nslmzVYQj1r8m85lyt
# To: /content/stylegan2/carasubjektiv128x128.pkl
# 100% 382M/382M [00:03<00:00, 107MB/s]

# %%
# !wget  https://archive.org/download/wikiart-stylegan2-conditional-model/network-snapshot-012052.pkl
# Out:
# --2022-05-17 00:35:12--  https://archive.org/download/wikiart-stylegan2-conditional-model/network-snapshot-012052.pkl
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia802803.us.archive.org/30/items/wikiart-stylegan2-conditional-model/network-snapshot-012052.pkl [following]
# --2022-05-17 00:35:12--  https://ia802803.us.archive.org/30/items/wikiart-stylegan2-conditional-model/network-snapshot-012052.pkl
# Resolving ia802803.us.archive.org (ia802803.us.archive.org)... 207.241.232.113
# Connecting to ia802803.us.archive.org (ia802803.us.archive.org)|207.241.232.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384781547 (367M) [application/octet-stream]
# Saving to: ‘network-snapshot-012052.pkl’
#
# network-snapshot-01 100%[===================>] 366.96M   433KB/s    in 11m 54s
#
# 2022-05-17 00:47:06 (526 KB/s) - ‘network-snapshot-012052.pkl’ saved [384781547/384781547]

# %%
# !python run_generator.py generate-images --network=/content/stylegan2/carasubjektiv128x128.pkl --seeds=200000-200050 --truncation-psi=0.6
# Out:
# Local submit - run_dir: results/00000-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "/content/stylegan2/carasubjektiv128x128.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Compiling... Loading... Done.
# Generating image for seed 200000 (1/51) ...
# Generating image for seed 200001 (2/51) ...
# Generating image for seed 200002 (3/51) ...
# Generating image for seed 200003 (4/51) ...
# Generating image for seed 200004 (5/51) ...
# Generating image for seed 200005 (6/51) ...
# Generating image for seed 200006 (7/51) ...
# Generating image for seed 200007 (8/51) ...
# Generating image for seed 200008 (9/51) ...
# Generating image for seed 200009 (10/51) ...
# Generating image for seed 200010 (11/51) ...
# Generating image for seed 200011 (12/51) ...
# Generating image for seed 200012 (13/51) ...
# Generating image for seed 200013 (14/51) ...
# Generating image for seed 200014 (15/51) ...
# Generating image for seed 200015 (16/51) ...
# Generating image for seed 200016 (17/51) ...
# Generating image for seed 200017 (18/51) ...
# Generating image for seed 200018 (19/51) ...
# Generating image for seed 200019 (20/51) ...
# Generating image for seed 200020 (21/51) ...
# Generating image for seed 200021 (22/51) ...
# Generating image for seed 200022 (23/51) ...
# Generating image for seed 200023 (24/51) ...
# Generating image for seed 200024 (25/51) ...
# Generating image for seed 200025 (26/51) ...
# Generating image for seed 200026 (27/51) ...
# Generating image for seed 200027 (28/51) ...
# Generating image for seed 200028 (29/51) ...
# Generating image for seed 200029 (30/51) ...
# Generating image for seed 200030 (31/51) ...
# Generating image for seed 200031 (32/51) ...
# Generating image for seed 200032 (33/51) ...
# Generating image for seed 200033 (34/51) ...
# Generating image for seed 200034 (35/51) ...
# Generating image for seed 200035 (36/51) ...
# Generating image for seed 200036 (37/51) ...
# Generating image for seed 200037 (38/51) ...
# Generating image for seed 200038 (39/51) ...
# Generating image for seed 200039 (40/51) ...
# Generating image for seed 200040 (41/51) ...
# Generating image for seed 200041 (42/51) ...
# Generating image for seed 200042 (43/51) ...
# Generating image for seed 200043 (44/51) ...
# Generating image for seed 200044 (45/51) ...
# Generating image for seed 200045 (46/51) ...
# Generating image for seed 200046 (47/51) ...
# Generating image for seed 200047 (48/51) ...
# Generating image for seed 200048 (49/51) ...
# Generating image for seed 200049 (50/51) ...
# Generating image for seed 200050 (51/51) ...
# dnnlib: Finished run_generator.generate_images() in 1m 27s.

# %% [markdown]
# Let’s zip the generated files and download them.

# %%
# !zip -r mundanetoaster2.zip /content/stylegan2/results/00000-generate-images
# Out:
#   adding: content/stylegan2/results/00000-generate-images/ (stored 0%)
#   adding: content/stylegan2/results/00000-generate-images/_finished.txt (stored 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200000.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200001.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200034.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200039.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200016.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200011.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200009.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/submit_config.txt (deflated 53%)
#   adding: content/stylegan2/results/00000-generate-images/seed200035.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200044.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200018.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200008.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200002.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200023.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200049.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200014.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200050.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200042.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200048.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200038.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/log.txt (deflated 82%)
#   adding: content/stylegan2/results/00000-generate-images/seed200030.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200021.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200024.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200031.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200041.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200006.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200012.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200033.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200032.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200027.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200046.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200004.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200010.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200007.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200036.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200040.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/run.txt (deflated 32%)
#   adding: content/stylegan2/results/00000-generate-images/seed200047.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/submit_config.pkl (deflated 43%)
#   adding: content/stylegan2/results/00000-generate-images/seed200022.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200029.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200026.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200020.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200003.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200017.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200028.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200037.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200043.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200015.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200005.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200045.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200013.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200025.png (deflated 0%)
#   adding: content/stylegan2/results/00000-generate-images/seed200019.png (deflated 0%)

# %% [markdown]
# #Interpolation

# %%
# !python run_generator.py generate-latent-walk --network=/content/stylegan2/carasubjektiv128x128.pkl --seeds=200019,200000,200030 --frames 400 --truncation-psi=0.6
# Out:
# Local submit - run_dir: results/00002-generate-latent-walk
# dnnlib: Running run_generator.generate_latent_walk() on localhost...
# Loading networks from "/content/stylegan2/carasubjektiv128x128.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# not enough values to generate walk
# Generating image for step 0/402 ...
# Generating image for step 1/402 ...
# Generating image for step 2/402 ...
# Generating image for step 3/402 ...
# Generating image for step 4/402 ...
# Generating image for step 5/402 ...
# Generating image for step 6/402 ...
# Generating image for step 7/402 ...
# Generating image for step 8/402 ...
# Generating image for step 9/402 ...
# Generating image for step 10/402 ...
# Generating image for step 11/402 ...
# Generating image for step 12/402 ...
# Generating image for step 13/402 ...
# Generating image for step 14/402 ...
# Generating image for step 15/402 ...
# Generating image for step 16/402 ...
# Generating image for step 17/402 ...
# Generating image for step 18/402 ...
# Generating image for step 19/402 ...
# Generating image for step 20/402 ...
# Generating image for step 21/402 ...
# Generating image for step 22/402 ...
# Generating image for step 23/402 ...
# Generating image for step 24/402 ...
# Generating image for step 25/402 ...
# Generating image for step 26/402 ...
# Generating image for step 27/402 ...
# Generating image for step 28/402 ...
# Generating image for step 29/402 ...
# Generating image for step 30/402 ...
# Generating image for step 31/402 ...
# Generating image for step 32/402 ...
# Generating image for step 33/402 ...
# Generating image for step 34/402 ...
# Generating image for step 35/402 ...
# Generating image for step 36/402 ...
# Generating image for step 37/402 ...
# Generating image for step 38/402 ...
# Generating image for step 39/402 ...
# Generating image for step 40/402 ...
# Generating image for step 41/402 ...
# Generating image for step 42/402 ...
# Generating image for step 43/402 ...
# Generating image for step 44/402 ...
# Generating image for step 45/402 ...
# Generating image for step 46/402 ...
# Generating image for step 47/402 ...
# Generating image for step 48/402 ...
# Generating image for step 49/402 ...
# Generating image for step 50/402 ...
# Generating image for step 51/402 ...
# Generating image for step 52/402 ...
# Generating image for step 53/402 ...
# Generating image for step 54/402 ...
# Generating image for step 55/402 ...
# Generating image for step 56/402 ...
# Generating image for step 57/402 ...
# Generating image for step 58/402 ...
# Generating image for step 59/402 ...
# Generating image for step 60/402 ...
# Generating image for step 61/402 ...
# Generating image for step 62/402 ...
# Generating image for step 63/402 ...
# Generating image for step 64/402 ...
# Generating image for step 65/402 ...
# Generating image for step 66/402 ...
# Generating image for step 67/402 ...
# Generating image for step 68/402 ...
# Generating image for step 69/402 ...
# Generating image for step 70/402 ...
# Generating image for step 71/402 ...
# Generating image for step 72/402 ...
# Generating image for step 73/402 ...
# Generating image for step 74/402 ...
# Generating image for step 75/402 ...
# Generating image for step 76/402 ...
# Generating image for step 77/402 ...
# Generating image for step 78/402 ...
# Generating image for step 79/402 ...
# Generating image for step 80/402 ...
# Generating image for step 81/402 ...
# Generating image for step 82/402 ...
# Generating image for step 83/402 ...
# Generating image for step 84/402 ...
# Generating image for step 85/402 ...
# Generating image for step 86/402 ...
# Generating image for step 87/402 ...
# Generating image for step 88/402 ...
# Generating image for step 89/402 ...
# Generating image for step 90/402 ...
# Generating image for step 91/402 ...
# Generating image for step 92/402 ...
# Generating image for step 93/402 ...
# Generating image for step 94/402 ...
# Generating image for step 95/402 ...
# Generating image for step 96/402 ...
# Generating image for step 97/402 ...
# Generating image for step 98/402 ...
# Generating image for step 99/402 ...
# Generating image for step 100/402 ...
# Generating image for step 101/402 ...
# Generating image for step 102/402 ...
# Generating image for step 103/402 ...
# Generating image for step 104/402 ...
# Generating image for step 105/402 ...
# Generating image for step 106/402 ...
# Generating image for step 107/402 ...
# Generating image for step 108/402 ...
# Generating image for step 109/402 ...
# Generating image for step 110/402 ...
# Generating image for step 111/402 ...
# Generating image for step 112/402 ...
# Generating image for step 113/402 ...
# Generating image for step 114/402 ...
# Generating image for step 115/402 ...
# Generating image for step 116/402 ...
# Generating image for step 117/402 ...
# Generating image for step 118/402 ...
# Generating image for step 119/402 ...
# Generating image for step 120/402 ...
# Generating image for step 121/402 ...
# Generating image for step 122/402 ...
# Generating image for step 123/402 ...
# Generating image for step 124/402 ...
# Generating image for step 125/402 ...
# Generating image for step 126/402 ...
# Generating image for step 127/402 ...
# Generating image for step 128/402 ...
# Generating image for step 129/402 ...
# Generating image for step 130/402 ...
# Generating image for step 131/402 ...
# Generating image for step 132/402 ...
# Generating image for step 133/402 ...
# Generating image for step 134/402 ...
# Generating image for step 135/402 ...
# Generating image for step 136/402 ...
# Generating image for step 137/402 ...
# Generating image for step 138/402 ...
# Generating image for step 139/402 ...
# Generating image for step 140/402 ...
# Generating image for step 141/402 ...
# Generating image for step 142/402 ...
# Generating image for step 143/402 ...
# Generating image for step 144/402 ...
# Generating image for step 145/402 ...
# Generating image for step 146/402 ...
# Generating image for step 147/402 ...
# Generating image for step 148/402 ...
# Generating image for step 149/402 ...
# Generating image for step 150/402 ...
# Generating image for step 151/402 ...
# Generating image for step 152/402 ...
# Generating image for step 153/402 ...
# Generating image for step 154/402 ...
# Generating image for step 155/402 ...
# Generating image for step 156/402 ...
# Generating image for step 157/402 ...
# Generating image for step 158/402 ...
# Generating image for step 159/402 ...
# Generating image for step 160/402 ...
# Generating image for step 161/402 ...
# Generating image for step 162/402 ...
# Generating image for step 163/402 ...
# Generating image for step 164/402 ...
# Generating image for step 165/402 ...
# Generating image for step 166/402 ...
# Generating image for step 167/402 ...
# Generating image for step 168/402 ...
# Generating image for step 169/402 ...
# Generating image for step 170/402 ...
# Generating image for step 171/402 ...
# Generating image for step 172/402 ...
# Generating image for step 173/402 ...
# Generating image for step 174/402 ...
# Generating image for step 175/402 ...
# Generating image for step 176/402 ...
# Generating image for step 177/402 ...
# Generating image for step 178/402 ...
# Generating image for step 179/402 ...
# Generating image for step 180/402 ...
# Generating image for step 181/402 ...
# Generating image for step 182/402 ...
# Generating image for step 183/402 ...
# Generating image for step 184/402 ...
# Generating image for step 185/402 ...
# Generating image for step 186/402 ...
# Generating image for step 187/402 ...
# Generating image for step 188/402 ...
# Generating image for step 189/402 ...
# Generating image for step 190/402 ...
# Generating image for step 191/402 ...
# Generating image for step 192/402 ...
# Generating image for step 193/402 ...
# Generating image for step 194/402 ...
# Generating image for step 195/402 ...
# Generating image for step 196/402 ...
# Generating image for step 197/402 ...
# Generating image for step 198/402 ...
# Generating image for step 199/402 ...
# Generating image for step 200/402 ...
# Generating image for step 201/402 ...
# Generating image for step 202/402 ...
# Generating image for step 203/402 ...
# Generating image for step 204/402 ...
# Generating image for step 205/402 ...
# Generating image for step 206/402 ...
# Generating image for step 207/402 ...
# Generating image for step 208/402 ...
# Generating image for step 209/402 ...
# Generating image for step 210/402 ...
# Generating image for step 211/402 ...
# Generating image for step 212/402 ...
# Generating image for step 213/402 ...
# Generating image for step 214/402 ...
# Generating image for step 215/402 ...
# Generating image for step 216/402 ...
# Generating image for step 217/402 ...
# Generating image for step 218/402 ...
# Generating image for step 219/402 ...
# Generating image for step 220/402 ...
# Generating image for step 221/402 ...
# Generating image for step 222/402 ...
# Generating image for step 223/402 ...
# Generating image for step 224/402 ...
# Generating image for step 225/402 ...
# Generating image for step 226/402 ...
# Generating image for step 227/402 ...
# Generating image for step 228/402 ...
# Generating image for step 229/402 ...
# Generating image for step 230/402 ...
# Generating image for step 231/402 ...
# Generating image for step 232/402 ...
# Generating image for step 233/402 ...
# Generating image for step 234/402 ...
# Generating image for step 235/402 ...
# Generating image for step 236/402 ...
# Generating image for step 237/402 ...
# Generating image for step 238/402 ...
# Generating image for step 239/402 ...
# Generating image for step 240/402 ...
# Generating image for step 241/402 ...
# Generating image for step 242/402 ...
# Generating image for step 243/402 ...
# Generating image for step 244/402 ...
# Generating image for step 245/402 ...
# Generating image for step 246/402 ...
# Generating image for step 247/402 ...
# Generating image for step 248/402 ...
# Generating image for step 249/402 ...
# Generating image for step 250/402 ...
# Generating image for step 251/402 ...
# Generating image for step 252/402 ...
# Generating image for step 253/402 ...
# Generating image for step 254/402 ...
# Generating image for step 255/402 ...
# Generating image for step 256/402 ...
# Generating image for step 257/402 ...
# Generating image for step 258/402 ...
# Generating image for step 259/402 ...
# Generating image for step 260/402 ...
# Generating image for step 261/402 ...
# Generating image for step 262/402 ...
# Generating image for step 263/402 ...
# Generating image for step 264/402 ...
# Generating image for step 265/402 ...
# Generating image for step 266/402 ...
# Generating image for step 267/402 ...
# Generating image for step 268/402 ...
# Generating image for step 269/402 ...
# Generating image for step 270/402 ...
# Generating image for step 271/402 ...
# Generating image for step 272/402 ...
# Generating image for step 273/402 ...
# Generating image for step 274/402 ...
# Generating image for step 275/402 ...
# Generating image for step 276/402 ...
# Generating image for step 277/402 ...
# Generating image for step 278/402 ...
# Generating image for step 279/402 ...
# Generating image for step 280/402 ...
# Generating image for step 281/402 ...
# Generating image for step 282/402 ...
# Generating image for step 283/402 ...
# Generating image for step 284/402 ...
# Generating image for step 285/402 ...
# Generating image for step 286/402 ...
# Generating image for step 287/402 ...
# Generating image for step 288/402 ...
# Generating image for step 289/402 ...
# Generating image for step 290/402 ...
# Generating image for step 291/402 ...
# Generating image for step 292/402 ...
# Generating image for step 293/402 ...
# Generating image for step 294/402 ...
# Generating image for step 295/402 ...
# Generating image for step 296/402 ...
# Generating image for step 297/402 ...
# Generating image for step 298/402 ...
# Generating image for step 299/402 ...
# Generating image for step 300/402 ...
# Generating image for step 301/402 ...
# Generating image for step 302/402 ...
# Generating image for step 303/402 ...
# Generating image for step 304/402 ...
# Generating image for step 305/402 ...
# Generating image for step 306/402 ...
# Generating image for step 307/402 ...
# Generating image for step 308/402 ...
# Generating image for step 309/402 ...
# Generating image for step 310/402 ...
# Generating image for step 311/402 ...
# Generating image for step 312/402 ...
# Generating image for step 313/402 ...
# Generating image for step 314/402 ...
# Generating image for step 315/402 ...
# Generating image for step 316/402 ...
# Generating image for step 317/402 ...
# Generating image for step 318/402 ...
# Generating image for step 319/402 ...
# Generating image for step 320/402 ...
# Generating image for step 321/402 ...
# Generating image for step 322/402 ...
# Generating image for step 323/402 ...
# Generating image for step 324/402 ...
# Generating image for step 325/402 ...
# Generating image for step 326/402 ...
# Generating image for step 327/402 ...
# Generating image for step 328/402 ...
# Generating image for step 329/402 ...
# Generating image for step 330/402 ...
# Generating image for step 331/402 ...
# Generating image for step 332/402 ...
# Generating image for step 333/402 ...
# Generating image for step 334/402 ...
# Generating image for step 335/402 ...
# Generating image for step 336/402 ...
# Generating image for step 337/402 ...
# Generating image for step 338/402 ...
# Generating image for step 339/402 ...
# Generating image for step 340/402 ...
# Generating image for step 341/402 ...
# Generating image for step 342/402 ...
# Generating image for step 343/402 ...
# Generating image for step 344/402 ...
# Generating image for step 345/402 ...
# Generating image for step 346/402 ...
# Generating image for step 347/402 ...
# Generating image for step 348/402 ...
# Generating image for step 349/402 ...
# Generating image for step 350/402 ...
# Generating image for step 351/402 ...
# Generating image for step 352/402 ...
# Generating image for step 353/402 ...
# Generating image for step 354/402 ...
# Generating image for step 355/402 ...
# Generating image for step 356/402 ...
# Generating image for step 357/402 ...
# Generating image for step 358/402 ...
# Generating image for step 359/402 ...
# Generating image for step 360/402 ...
# Generating image for step 361/402 ...
# Generating image for step 362/402 ...
# Generating image for step 363/402 ...
# Generating image for step 364/402 ...
# Generating image for step 365/402 ...
# Generating image for step 366/402 ...
# Generating image for step 367/402 ...
# Generating image for step 368/402 ...
# Generating image for step 369/402 ...
# Generating image for step 370/402 ...
# Generating image for step 371/402 ...
# Generating image for step 372/402 ...
# Generating image for step 373/402 ...
# Generating image for step 374/402 ...
# Generating image for step 375/402 ...
# Generating image for step 376/402 ...
# Generating image for step 377/402 ...
# Generating image for step 378/402 ...
# Generating image for step 379/402 ...
# Generating image for step 380/402 ...
# Generating image for step 381/402 ...
# Generating image for step 382/402 ...
# Generating image for step 383/402 ...
# Generating image for step 384/402 ...
# Generating image for step 385/402 ...
# Generating image for step 386/402 ...
# Generating image for step 387/402 ...
# Generating image for step 388/402 ...
# Generating image for step 389/402 ...
# Generating image for step 390/402 ...
# Generating image for step 391/402 ...
# Generating image for step 392/402 ...
# Generating image for step 393/402 ...
# Generating image for step 394/402 ...
# Generating image for step 395/402 ...
# Generating image for step 396/402 ...
# Generating image for step 397/402 ...
# Generating image for step 398/402 ...
# Generating image for step 399/402 ...
# Generating image for step 400/402 ...
# Generating image for step 401/402 ...
# dnnlib: Finished run_generator.generate_latent_walk() in 5m 03s.

# %%
#convert to video 
# !ffmpeg -r 20 -i ./results/00002-generate-latent-walk/%*.png  -vcodec libx264 -pix_fmt yuv420p output.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# [image2 @ 0x55996b334000] Pattern type 'glob_sequence' is deprecated: use pattern_type 'glob' instead
# Input #0, image2, from './results/00002-generate-latent-walk/%*.png':
#   Duration: 00:00:16.08, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55996b339e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55996b339e00] profile High, level 3.2
# [libx264 @ 0x55996b339e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=20 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 20 fps, 10240 tbn, 20 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  402 fps= 12 q=-1.0 Lsize=    6613kB time=00:00:19.95 bitrate=2715.5kbits/s speed=0.616x
# video:6610kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041838%
# [libx264 @ 0x55996b339e00] frame I:2     Avg QP:19.51  size:125085
# [libx264 @ 0x55996b339e00] frame P:378   Avg QP:21.73  size: 17138
# [libx264 @ 0x55996b339e00] frame B:22    Avg QP:24.48  size:  1807
# [libx264 @ 0x55996b339e00] consecutive B-frames: 91.8%  2.0%  2.2%  4.0%
# [libx264 @ 0x55996b339e00] mb I  I16..4:  1.3% 77.0% 21.7%
# [libx264 @ 0x55996b339e00] mb P  I16..4:  0.1%  0.5%  0.0%  P16..4: 45.9% 13.8% 12.6%  0.0%  0.0%    skip:27.1%
# [libx264 @ 0x55996b339e00] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 24.8%  0.3%  0.1%  direct: 0.9%  skip:73.8%  L0:19.6% L1:77.3% BI: 3.1%
# [libx264 @ 0x55996b339e00] 8x8 transform intra:79.3% inter:61.8%
# [libx264 @ 0x55996b339e00] coded y,uvDC,uvAC intra: 84.1% 64.1% 29.9% inter: 35.1% 26.0% 0.3%
# [libx264 @ 0x55996b339e00] i16 v,h,dc,p: 22% 14% 21% 44%
# [libx264 @ 0x55996b339e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 11% 17%  6% 12% 14%  9%  9%  8%
# [libx264 @ 0x55996b339e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 10% 10%  7% 17% 15% 10%  8%  7%
# [libx264 @ 0x55996b339e00] i8c dc,h,v,p: 60% 15% 18%  7%
# [libx264 @ 0x55996b339e00] Weighted P-Frames: Y:5.6% UV:0.3%
# [libx264 @ 0x55996b339e00] ref P L0: 69.7% 27.1%  2.8%  0.4%  0.0%
# [libx264 @ 0x55996b339e00] ref B L0: 96.4%  3.2%  0.3%
# [libx264 @ 0x55996b339e00] ref B L1: 99.3%  0.7%
# [libx264 @ 0x55996b339e00] kb/s:2693.84
